# %%
# df_products=spark.read.format("Delta").load("olist.bronze.crm_olit_products")

# %%
df_products=spark.read.table("olist.bronze.crm_olist_products")

# %%
display(df_products)

# %%
# %sql
SELECT *
FROM olist.bronze.crm_olist_products
WHERE product_name_lenght

 != TRIM(product_name_lenght

);

# %%
columnsList=["product_name_lenght", "product_description_lenght", "product_photos_qty", "product_weight_g", "product_length_cm", "product_height_cm", "product_width_cm"]

for i in columnsList:
    df_products=df_products.withColumn(i, df_products[i].cast("int"))

# %%
display(df_products)
