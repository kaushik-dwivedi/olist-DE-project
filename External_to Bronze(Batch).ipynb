# %% [markdown]
# ## Loading Batch data into Bronze layer

# %%
# %run "/Workspace/Users/kaushikdwivedi22@gmail.com/olist-DE-project/cred"

# %%
df_customers = spark.read.option("header", "true").format("csv").load(f"{basepath}/CRM/Customers")
df_customers.write.mode("overwrite").saveAsTable("olist.bronze.CRM_olist_customers")

# %%
df_products=spark.read.option("header", "true").format("csv").load(f"{basepath}/CRM/Products")
df_products.write.mode("overwrite").saveAsTable("olist.bronze.CRM_olist_products")

# %%
df_sellers=spark.read.option("header", "true").format("csv").load(f"{basepath}/CRM/Sellers")
df_sellers.write.mode("overwrite").saveAsTable("olist.bronze.CRM_olist_sellers")

# %% [markdown]
# CRM DONE
